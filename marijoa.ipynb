# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolasvargaszz/ML-models/blob/main/marijoa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pantone = pd.read_csv("pantone.csv")

# %%
pantone.head()
# Out:
#    pantone                        nombre_color  rgb  estado
# 0  00-0000                           SIN COLOR  NaN  Activo
# 1  00-0001                      BLANCO AZULADO  NaN  Activo
# 2  00-0002  AZUL CLEMATIS/AMARILLO GREEN SHEEN  NaN  Activo
# 3  00-0003         AZUL ROYAL/BLANCO BRILLANTE  NaN  Activo
# 4  00-0004       AZUL PEACOAT/BLANCO BRILLANTE  NaN  Activo

# %%
pantone.shape
# Out:
# (1740, 4)

# %%
factura = pd.read_csv("fact_vent_det.csv")
# Out:
# id_det                                             2
# f_nro                                              2
# lote                                             NaN
# codigo                                         SR003
# um_prod                                         Unid
# descrip          MIGRACION DE DEUDA SISTEMA ANTERIOR
# sku                                              NaN
# um_cod                                          Unid
# cantidad                                         1.0
# cod_falla                                        NaN
# cant_falla                                       NaN
# cod_falla_e                                      NaN
# falla_real                                       NaN
# precio_venta                               9000000.0
# descuento                                        0.0
# precio_neto                                9000000.0
# subtotal                                   9000000.0
# tipo_iva                                         NaN
# ...

# %%
sectores= pd.read_csv("sectores.csv")

# %%
print(sectores)
# Out:
#     cod_sector             descrip prefijo  longitud  serie
# 0          101             BASICOS       B         4    156
# 1          102               HOGAR       H         4    328
# 2          103             CRUCERO       C         4    254
# 3          104           SASTRERIA       S         4    287
# 4          106             INSUMOS      IN         3    414
# 5          107             ACTIVOS      AC         3     52
# 6          108  PRODUCTO_TERMINADO      TX         3    200
# 7          109              VARIOS      RV         3     26
# 8          110           SERVICIOS      SR         3     16
# 9          111            BASCULAS      BS         3     87
# 10         112        MANO DE OBRA      MO         3      1
# 11         113          HORMIFORTE      HO         3     37

# %%
factura_venta = pd.read_csv("factura_venta.csv")
# Out:
# <ipython-input-21-53b1ef978d3d>:1: DtypeWarning: Columns (19,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   factura_venta = pd.read_csv("factura_venta.csv")

# %%
factura_venta.head(5)
# Out:
#    f_nro  cod_cli                                      cliente  usuario  \
# 0      1  C003403        ANALISE PIAZZA MELGAREJO - MODA CHICK  Sistema
# 1      2  C110877  EDISON AVELINO PRIETO RAMIREZ - PyC Brindis  Sistema
# 2      3  C000021                      EDORITA ZOTELO MARTINEZ  Sistema
# 3      4  C001968                      ELVA LILIANA ZARZA ARCE  Sistema
# 4      5  C001968                      ELVA LILIANA ZARZA ARCE  Sistema
#
#         fecha   hora  turno    ruc_cli tipo_doc_cli  suc  ...  \
# 0  2015-06-23  07:00    0.0  7360941-2         R.G.    5  ...
# 1  2013-02-27  07:00    0.0  3682773-8          NaN    5  ...
# 2  2014-11-04  07:00    0.0  1716670-5         C.I.    1  ...
# 3  2015-06-29  07:00    0.0  3465944-7         C.I.    6  ...
# 4  2015-07-31  07:00    0.0  3465944-7         C.I.    6  ...
#
#    turno_repeticiones                                       notas     clase  \
# 0                 NaN   Migracion deuda SAP Doc: 29  MarijoaSAP:   Servicio
# ...

# %%
factura_venta.columns
# Out:
# Index(['f_nro', 'cod_cli', 'cliente', 'usuario', 'fecha', 'hora', 'turno',
#        'ruc_cli', 'tipo_doc_cli', 'suc', 'cat', 'total_exenta', 'total_iva5',
#        'total_iva10', 'total', 'desc_sedeco', 'total_desc', 'total_bruto',
#        'estado', 'pdv_cod', 'fact_nro', 'tipo_fact', 'tipo_doc', 'pdv_ubic',
#        'nro_recibo', 'cod_desc', 'empaque', 'pref_pago', 'fecha_cierre',
#        'hora_cierre', 'nro_reserva', 'moneda', 'cotiz', 'control_caja',
#        'cant_cuotas', 'tipo', 'empaquetador', 'nro_orden', 'orden_cli',
#        'orden_valor', 'turno_id', 'turno_fecha', 'turno_llamada',
#        'turno_atencion', 'turno_repeticiones', 'notas', 'clase',
#        'ticket_print', 'fecha_caducidad', 'e_sap', 'nro_orden_shopify',
#        'sifen_sync', 'cdc', 'bd_f_nro'],
#       dtype='object')

# %%
lotes = pd.read_csv("lotes.csv")

# %%
lotes.head(5)
# Out:
#   codigo      lote  cod_serie  pantone   umc um_prod  nro_lote_fab  \
# 0  AC001   5231922         22  00-0000  Unid    Unid           1.0
# 1  AC001   5232022         22  00-0000  Unid    Unid           1.0
# 2  AC001   5232122         22  00-0000  Unid    Unid           1.0
# 3  AC001   5232222         22  00-0000  Unid    Unid           1.0
# 4  AC003  10965817         17  00-0000  Unid    Unid           NaN
#
#         store  bag  nro_pieza  ...  notas                 img  padre  rec  \
# 0  CTXW22067   1.0      334.0  ...    NaN  OPDN-1948/16892518    NaN   Si
# 1  CTXW22067   1.0      335.0  ...    NaN  OPDN-1948/16892518    NaN   Si
# 2  CTXW22067   1.0      336.0  ...    NaN  OPDN-1948/16892518    NaN   Si
# 3  CTXW22067   1.0      337.0  ...    NaN  OPDN-1948/16892518    NaN   Si
# 4         NaN  0.0        0.0  ...    NaN                 NaN    NaN   Si
#
#         fecha_creacion   id_ent  id_det id_frac id_prod_ter id_compra
# ...

# %%
lotes.shape
# Out:
# (211213, 31)

# %%
unidades_medida= pd.read_csv("unidades_medida.csv")

# %%
unidades_medida
# Out:
#   um_cod    um_descri um_ref  um_mult  um_prior  um_cod_set
# 0     Cm  Centimetros    Mts    0.010         5         NaN
# 1     Gr       Gramos     Kg    0.001         6         NaN
# 2     Kg   Kilogramos    NaN    1.000         3         NaN
# 3    Mts       Metros    NaN    1.000         1         NaN
# 4   Unid     Unidades    NaN    1.000         2         NaN
# 5    Yds       Yardas    Mts    0.914         4         NaN

# %% [markdown]
# # **Tablas mas importantes**

# %%
factura_venta.iloc[0]
# Out:
# f_nro                                                         1
# cod_cli                                                 C003403
# cliente                   ANALISE PIAZZA MELGAREJO - MODA CHICK
# usuario                                                 Sistema
# fecha                                                2015-06-23
# hora                                                      07:00
# turno                                                       0.0
# ruc_cli                                               7360941-2
# tipo_doc_cli                                               R.G.
# suc                                                           5
# cat                                                           5
# total_exenta                                                NaN
# total_iva5                                                  NaN
# total_iva10                                                 NaN
# total                                                41172980.0
# ...

# %%
factura.iloc[0]
# Out:
# id_det                                             1
# f_nro                                              1
# lote                                             NaN
# codigo                                         SR003
# um_prod                                         Unid
# descrip          MIGRACION DE DEUDA SISTEMA ANTERIOR
# sku                                              NaN
# um_cod                                          Unid
# cantidad                                         1.0
# cod_falla                                        NaN
# cant_falla                                       NaN
# cod_falla_e                                      NaN
# falla_real                                       NaN
# precio_venta                              41172980.0
# descuento                                        0.0
# precio_neto                               41172980.0
# subtotal                                  41172980.0
# tipo_iva                                         NaN
# ...

# %%
lotes.iloc[0]
# Out:
# codigo                           AC001
# lote                           5231922
# cod_serie                           22
# pantone                        00-0000
# umc                               Unid
# um_prod                           Unid
# nro_lote_fab                       1.0
# store                       CTXW22067
# bag                                1.0
# nro_pieza                        334.0
# ancho                              1.0
# gramaje                            1.0
# gramaje_m                          1.0
# tara                               0.0
# kg_desc                           0.68
# quty_ticket                        1.0
# quty_c_um                          1.0
# color_comb                     NINGUNO
# cod_catalogo                     SHELF
# color_cod_fabric               STARTER
# design                            LISO
# notas                              NaN
# img                 OPDN-1948/16892518
# padre                              NaN
# ...

# %%
articulos = pd.read_csv("articulos.csv")

# %%
articulos.iloc[100]
# Out:
# codigo                                  B0049
# clase                                Articulo
# descrip                    MANTILLA LANILLADA
# cod_sector                                101
# um                                        Mts
# costo_prom                             2527.0
# costo_cif                                 0.0
# costo_fob                                 NaN
# art_venta                                True
# art_inv                                  True
# art_compra                               True
# art_gramado                              True
# img                                       NaN
# estado_venta                           Normal
# composicion                         POLIESTER
# temporada                             Oto-Inv
# ligamento                            Urdimbre
# combinacion                   REVES CON FELPA
# especificaciones    TELA ORNAMENTAL Y TERMICA
# acabado                                  Mate
# ...

# %%
valores_unicos = articulos['ligamento'].unique()
valores_unicos
# Out:
# array(['No Tejido', nan, 'Jersey', 'Por Trama', 'Tricot/Jersey', 'Ribb',
#        'Tafetan', 'Tafetán', 'Interlock', 'JERSEY', 'Urdimbre', 'Malla',
#        'Pique', 'TAFETAN', 'INTERLOCK', 'RIBB', 'INTERLOCK ', 'interlock',
#        'Interlock/PIQUE', 'JACQUARD', 'Jersey Terry ', 'jersey terry',
#        'PIQUE', 'Saten', 'POR Urdimbre', 'Satén', 'Por Urdimbre', 'SATEN',
#        'URDIMBRE', 'jacquard', 'Jacquard', 'JACARD', 'TRAMA',
#        'Punto por Urdimbre', 'Punto', 'No tejido', 'POR URDIMBRE',
#        'JERSEY TERRY', 'TAFETÁN', 'TafetÁn', 'Tafetán/Satén',
#        'Tafetan/Saten', 'Jacquard ', 'Sarga', 'Tafetan/Sarga', 'Twill',
#        'TAFETáN', 'jacquard/TAFETAN', 'ES POR TRAMA', 'NINGUNO',
#        'NO TEJIDO', 'Tweed', 'Sarga/Saten', 'Punto Marsella', 'TafetAN',
#        'SARGA', 'no tejido'], dtype=object)

# %% [markdown]
# # ***Limpieza de datos:***
